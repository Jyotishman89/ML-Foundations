# %%
import numpy as np

marks = np.array([72, 85, 90, 65, 78, 92, 68, 75, 88, 80])

print("Mean:", np.mean(marks))
print("Median:", np.median(marks))
print("Range:", np.max(marks) - np.min(marks))
print("Variance (sample):", np.var(marks, ddof=1))
print("Std Deviation (sample):", np.std(marks, ddof=1))

# %%
# !git add Statistics/Statistics_with_Numpy.ipynb

# %%
# !git commit --amend --no-edit

# %%
# !git push origin main

# %%
# !git remote set-url origin https://Jyotishman89:<YOUR_TOKEN_HERE>@github.com/Jyotishman89/ML-Foundations.git

# %%
# !git push origin main

# %%
# !git reset --soft HEAD~1

# %%
# !git add .
# !git commit -m "Added Statistics with Numpy assignment - outputs cleared"

# %%
# !git push origin main
